# %% [markdown]
# <a href="https://colab.research.google.com/github/zakariazemmahi/waste-detection-yolov8/blob/main/Models/Smart_waste_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: installer le bib ultralytics
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# # **Télécharger les bib nécessaire**

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %% [markdown]
# # **Télécharger le dataset**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uXkhiggzj2db1iGwW5gH")
project = rf.workspace("cleanvision-ensam").project("smartwastedetector")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to SmartWasteDetector-3 in yolov8:: 100%|██████████| 2960/2960 [00:01<00:00, 2858.43it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Télécharger le dataset
dataset = version.download("yolov8")

# Entraîner le modèle avec le dataset téléchargé
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 131MB/s]
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move the trained model to Google Drive
# !cp runs/detect/train/weights/best.pt /content/drive/MyDrive/yolov8_best_smartdetection.pt

# %%
# !cp runs/detect/train/weights/best.pt /content/drive/MyDrive/yolov8_best_smartdetection1.pt

# %%
from ultralytics import YOLO

# Charger ton modèle entraîné
model = YOLO("/content/drive/MyDrive/yolov8_best_smartdetection.pt")

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Charger le modèle
model = YOLO("/content/drive/MyDrive/yolov8_best_smartdetection.pt")

# Prédire sur l'image
results = model.predict(source="image3.jpg", conf=0.25)

# Obtenir l'image annotée
annotated_img = results[0].plot()

# Afficher avec matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Résultat de détection")
plt.show()
# Out:
# image 1/1 /content/image3.jpg: 640x480 1 dechet, 12.9ms
# Speed: 3.3ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8_best_smartdetection.pt source="image.jpg"
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/image.jpg: 640x480 1 non_dechet, 40.5ms
# Speed: 4.1ms preprocess, 40.5ms inference, 139.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8_best_smartdetection.pt source="image1.jpg"
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/image1.jpg: 480x640 (no detections), 39.0ms
# Speed: 4.0ms preprocess, 39.0ms inference, 61.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8_best_smartdetection.pt source="image3.jpg"
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/image3.jpg: 640x480 (no detections), 40.3ms
# Speed: 4.4ms preprocess, 40.3ms inference, 25.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8_best_smartdetection.pt source="image4.jpg"
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/image4.jpg: 640x480 1 non_dechet, 41.7ms
# Speed: 3.4ms preprocess, 41.7ms inference, 154.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8_best_smartdetection.pt source="image5.jpg"
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/image5.jpg: 640x480 2 non_dechets, 52.2ms
# Speed: 4.0ms preprocess, 52.2ms inference, 139.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8_best_smartdetection.pt source="image6.jpg"
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/image6.jpg: 480x640 2 dechets, 65.6ms
# Speed: 5.6ms preprocess, 65.6ms inference, 176.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict8
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
